# %%
import pandas as pd
import numpy as np

# %%
import json
with open ('../artifacts/kaggle.json' , 'r') as file:
    data=json.load(file)

# %%
data
# Out:
# {'username': 'gihansasamadini', 'key': '96de2c647c698838c9958969b738dc7e'}

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 2.2 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=14.05.14 in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (2026.6.17)
# Requirement already satisfied: idna in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (3.18)
# Collecting text-unidecode
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 10.4 MB/s eta 0:00:01
# Requirement already satisfied: bleach in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (6.2.0)
# Collecting python-slugify
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: setuptools>=21.0.0 in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (58.0.4)
# Requirement already satisfied: six>=1.10 in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: requests in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: webencodings in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (0.5.1)
# Collecting protobuf
#   Downloading protobuf-6.33.6-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
#      |████████████████████████████████| 427 kB 12.9 MB/s eta 0:00:01
# Requirement already satisfied: urllib3>=1.15.1 in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: tqdm in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (4.68.3)
# Requirement already satisfied: charset-normalizer in /Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (3.4.7)
# Installing collected packages: text-unidecode, python-slugify, protobuf, kaggle
# Successfully installed kaggle-1.7.4.5 protobuf-6.33.6 python-slugify-8.0.4 text-unidecode-1.3
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/gihansasamadini/Desktop/Sentiment-Analysis-Project/env/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
